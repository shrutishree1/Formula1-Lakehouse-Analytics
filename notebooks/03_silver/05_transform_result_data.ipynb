# %% [markdown]
# #### Steps taken:
# 1. Read bronze results data.
# 2. Keep only columns required for analytics, will drop the url column.
# 3. Standardize the column name using snake_case (ex: driverID -> driver_id, positionText -> finish_position_text etc.)
# 4. Rename columns to make it more meaningful.
# 5. Filter out rows where season, round, constructor_id, driver_id that is null (business key validation)
# 5. Remove duplicate records.
# 6. Transform values of columns to title case (ex: race_name).
# 7. Write the transform data to silver results table.

# %%
# %run ../environment_config

# %%
bronze_table = f"{catalog}.{bronze_schema}.results"
silver_table = f"{catalog}.{silver_schema}.results"

# %%
from pyspark.sql import functions as F

# %%
results_df = spark.read.table(bronze_table)\
                  .select("*").drop("url")\
                  .withColumnsRenamed({
                         "constructorId" : "constructor_id",
                         "date" : "race_date",
                         "driverID" : "driver_id",
                         "raceName" : "race_name",
                         "grid" : "grid_position",
                         "laps" : "completed_laps",
                         "number" : "car_number",
                         "position" : "final_position",
                         "positionText" : "final_position_text"
                  })

# %%
result_valid_df = results_df.filter(
                    F.col("season").isNotNull() &
                    F.col("round").isNotNull() &
                    F.col("constructor_id").isNotNull() &
                    F.col("driver_id").isNotNull() 
                     )

# %%
display(results_df.count() - result_valid_df.count())

# %%
display(result_valid_df.count())

# %%
results_distinct_df = result_valid_df.dropDuplicates(
                         ["season", "round", "driver_id", "constructor_id"]
                     )

# %%
display(results_distinct_df.count())

# %%
display(result_valid_df.count() - results_distinct_df.count())

# %%
results_final_df = results_distinct_df.withColumn(
                                "race_name", F.initcap(F.col("race_name"))
)

# %%
(
    results_final_df.write
                    .format("delta")
                    .mode("overwrite")
                    .saveAsTable(silver_table)
)

# %%
display(spark.table(silver_table))
